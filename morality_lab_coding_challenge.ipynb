# %% [markdown]
# <a href="https://colab.research.google.com/github/lypsychlab/coding-challenge/blob/main/morality_lab_coding_challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <h1 align="center">Instructions</h1>

# %% [markdown]
# Please don't spend too long on these tasks! If you find yourself dedicating an inordinate amount of time to any of these challenges, **it's absolutely fine to just sketch out your approach to the solution (pseudocode)** rather than detailing a perfectly complete answer. Please keep in mind that we're more interested in *how* you think about these problems than whether your syntax is perfect or if your code is optimized.

# %% [markdown]
# **NOTE:** Please ignore the following popup—we wrote the code! Just click "Run anyway."
#
# ![Screenshot 2023-05-07 at 9.48.30 PM.png](data:image/png;base64,...)

# %% [markdown]
# # **Q1: Python Challenge**
#
# The following challenge is a tabular data randomization problem. Currently, this code only produces a random list of 11 stories—it's missing one! Your task is to identify and correct the error in this function so that it successfully outputs all 12 stories.

# %% [markdown]
# ## **Python Challenge: View Data**
#
# The following code imports `numpy` and `pandas` data wrangling packages and reads in the .csv file for you to view.

# %%
import pandas as pd
import numpy as np


data_url = 'https://drive.google.com/uc?id=19_Uw98c__fTUSNmgSYy_YZP5E6yYL4Xe'

stimuli_df = pd.read_csv(data_url)
stimuli_df  # view the file

# %% [markdown]
# ## **Python Challenge: Let's Debug!**
#
# The following code packages all data transformation processes into one function. However, calling the function as it is currently written outputs only 11 of the 12 stories. How would you fix this error? Debug the following function, `q1()`, to ensure that its printed output includes all 12 stories.

# %%
def q1():
    """
    Randomizes stimulus presentation order
    :returns: Nothing, iteratively prints stimuli in random order
    """
    causality_q = []
    prevent_q = []
    scenario_text = []

    # Read in the stimulus data using pandas
    stimuli_df = pd.read_csv(data_url)

    for index, row in stimuli_df.iterrows():
        causality_q.append(
            f"Did you cause {row['root']}?")
        prevent_q.append(
            f"Could you have prevented {row['gerund']}?")
        scenario_text.append(
            f"{row['Background']} {row['Intentional version']}")

    # Initialize a dictionary to hold the stimulus questions
    questions = {
        'causality': causality_q,
        'preventability': prevent_q,
        'scenario_text': scenario_text
    }

    # Make a permutation to display questions in random order
    q_order = np.random.permutation(range(1, len(causality_q), 1))

    # Print the questions according to that order
    for i in q_order:
        print(f'Story Number {i+1}:')
        print(questions['scenario_text'][i])
        print(questions['causality'][i])
        print(questions['preventability'][i])
        print('\n')

# Call the function
q1()

# %% [markdown]
# # **Q2: R Challenge**

# %% [markdown]
# Some R code and comments are provided here. Parts that you need to fill in are marked with `<YOUR CODE HERE>`. Note: in the standard R console and RStudio IDE, you can highlight a chunk of code and run it using `⌘ Cmd` + `Enter`. However, this isn't the case in Co-Lab (but, local variables, functions, and data are still stored in RAM).
#
# Even if you are totally new to R, we encourage you to give this challenge a shot! This job will inevitably involve teaching yourself new skills that other people in the lab might not have. If you ever get stuck, know that there is lots of R documentation online, so if you need information, just search for it!
# For those who are familiar with R frameworks, please feel free to adopt base R, tidyverse, data.table approaches, or a mix of these—whatever you are most comfortable doing!
#
# **NOTE:** if any task below requires multiple lines of code, make a point of providing your own documentation to tell me (or anyone who might look at your code) what function that line or set of lines is supposed to serve. This way, if a bit of code doesn't work, I can at least understand what you were *trying* to do!

# %% [markdown]
# First, you'll need to run the code below to properly run R in Google Co-Lab. Please feel free to ignore the following warning in the output:
#
# ```{r}
# WARNING: The following packages were previously imported in this runtime:
#   [_rinterface_cffi_api,rpy2]
# You must restart the runtime in order to use newly installed versions
# ```
#
# **NOTE**: You will have to restart the kernel after downgrading before proceeding to the rest of the challenge; losing all local variables is fine! When you see the following message, click "Yes":
#
# ![Screenshot 2023-05-07 at 9.54.12 PM.png](data:image/png;base64,...)

# %%
# %load_ext rpy2.ipython

# Downgrade the pre-installed version of rpy2 to ensure R works here in Co-Lab
# !pip install rpy2==3.5.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rpy2==3.5.1 in /usr/local/lib/python3.10/dist-packages (3.5.1)
# Requirement already satisfied: cffi>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from rpy2==3.5.1) (1.15.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from rpy2==3.5.1) (2022.7.1)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from rpy2==3.5.1) (4.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from rpy2==3.5.1) (3.1.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.10.0->rpy2==3.5.1) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->rpy2==3.5.1) (2.1.2)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.10/dist-packages (from tzlocal->rpy2==3.5.1) (0.1.0.post0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from pytz-deprecation-shim->tzlocal->rpy2==3.5.1) (2023.3)

# %% [markdown]
# ## **R Challenge: Import/Export Packages + Data**

# %% [markdown]
# Install the packages `lme4` and `ggplot2`, and load them into your workspace. While most lab members prefer to use `tidyverse` syntax, you are welcome to implement the following exercises in base R or even `data.table`.
#
# **NOTE:** If you do this correctly, you will still have to be patient, as this process may take up to ~5 minutes depending on the strength of your internet connection. Please ignore any console output messages such as `WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:...`—these are just log messages, and it means you're installing everything correctly! If you do run into any problems with package installation, please first try restarting the kernel by going to the menu and clicking on Runtime > Restart runtime. If the problem persists, please feel free to reach out to us.

# %%
# %%R  # Do not edit, this ("R magic") is required for R to run in Co-Lab
# # Install and load `lme4` and `ggplot2`
# # <YOUR CODE HERE>

# %% [markdown]
# ## **R Challenge: Read in Code Challenge File**

# %% [markdown]
# The link to the data is [here](https://drive.google.com/uc?id=1DDUz-UnuGz3fzperOSLF2Li7Fbk73WzZ). Please feel free to either read the data in from this link or upload it to your temporary Co-Lab storage and reference its location there.

# %%
# %%R
# # Read in the q3_data.csv as a dataframe called 'rtpj_df'
# # <YOUR CODE HERE>
# Out:
# Rows: 2407 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): subject, conditions
# dbl (12): onset, -4, -2, 0, 2, 4, 6, 8, 10, 12, wrongness, run
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 2,407 × 14
#    subject        onset  `-4`   `-2`    `0`   `2`   `4`   `6`   `8`  `10`   `12`
#    <chr>          <dbl> <dbl>  <dbl>  <dbl> <dbl> <dbl> <dbl> <dbl> <dbl>  <dbl>
#  1 YOU_FIRSTTHIR…    19 -1.28 -1.58  -1.92  -2.02 -1.56 -1.56 -1.26 -1.59 -1.97
#  2 YOU_FIRSTTHIR…    36 -2.24 -2.17  -2.45  -2.15 -1.89 -1.96 -2.28 -2.09 -2.45
#  3 YOU_FIRSTTHIR…    63 -1.60 -1.06  -1.54  -2.04 -2.12 -1.99 -1.78 -1.70 -1.27
#  4 YOU_FIRSTTHIR…    79 -2.78 -2.68  -2.70  -2.27 -1.80 -1.56 -1.72 -2.01 -2.32
#  5 YOU_FIRSTTHIR…   100 -2.10 -2.21  -2.14  -2.04 -2.08 -1.91 -1.83 -1.14 -0.918
#  6 YOU_FIRSTTHIR…   107 -1.14 -0.918 -1.03  -1.13 -1.49 -1.68 -2.03 -2.07 -1.83
#  7 YOU_FIRSTTHIR…   139 -2.24 -2.59  -2.56  -2.25 -1.96 -2.10 -2.07 -2.16 -1.78
#  8 YOU_FIRSTTHIR…   148 -1.36 -1.44  -1.45  -1.75 -1.89 -1.95 -1.92 -2.06 -2.01
#  9 YOU_FIRSTTHIR…   155 -2.06 -2.01  -1.85  -1.63 -1.66 -1.81 -1.54 -1.97 -2.39
# 10 YOU_FIRSTTHIR…   181 -1.09 -0.791 -0.962 -1.43 -1.61 -1.48 -1.62 -2.12 -2.20
# # ℹ 2,397 more rows
# # ℹ 3 more variables: conditions <chr>, wrongness <dbl>, run <dbl>
# # ℹ Use `print(n = ...)` to see more rows

# %% [markdown]
# ## **R Challenge: Create Columns Conditionally**

# %% [markdown]
# This is a dataset with trial-by-trial neural activity (percent signal change, or PSC) from a region of the brain called the rTPJ, which the lab is *very* interested in. Each row corresponds to a trial of an fMRI experiment: the column `onset` tells you when, in a given run, that trial took place. For each trial, we have already extracted the PSC at 9 distinct time points: column 3 is the PSC 4 seconds before the start of a trial, column 5 is PSC at the start of the trial, and so on.
#
# The columns are already named in the following format:
#
# | subject | onset | -4 | -2 | 0 | 2 | 4 | 6 | 8 | 10 | 12 | conditions | wrongness | run |
# |---------|-------|----|----|---|---|---|---|---|----|----|-----------|----------|-----|
# |         |       |    |    |   |   |   |   |   |    |    |           |         |         |

# %% [markdown]
# Each trial belongs to an experimental condition (given in the `conditions` column—and there are 6 conditions in total). Participants also gave judgments of moral wrongness (on a scale from 1 = "not at all wrong" to 4 = "very wrong") at the end of each trial. These ratings can be found in the `wrongness` column.
#
# Our six conditions are derived from combinations of three independent variables: "agent," "patient," and "outcome." Here's how they break down:
#
# | condition | agent | outcome | patient |
# | --------- | ----- | ------- | ------- |
# | `1st_P_harm` | self | harm | other |
# | `1st_P_neut` | self | neutral | other |
# | `3rd_P_harm` | other | harm | other |
# | `3rd_P_neut` | other | neutral | other |
# | `comp_other` | computer | harm | other |
# | `comp_self` | computer | harm | self |

# %% [markdown]
# So that we can eventually test the independent contribution of each of these variables on various outcomes measures, please make 3 new columns, one for each independent variable: `agent`, `patient`, and `outcome`. These should contain the variable info as described above.

# %%
# %%R
# # Create and populate agent, patient, and outcome columns
# # <YOUR CODE HERE>

# %% [markdown]
# ## **R Challenge: Visualize Neural Time Course Data**

# %% [markdown]
# Now let's try to visualize the time course of neural activity for the different conditions! Use `ggplot2` to visualize a line plot showing PSC fluctuation over a trial (from `-4` to `12`), broken down by condition and averaged across participants and trials. The final product should have 6 different time courses (one for each condition) overlaid on top of each other. There are a number of ways to put this all together and design the plot, so get creative! As a bonus, add standard error bars to your plot!
#
# **NOTE:** You may need to install and load some other packages to achieve the desired result.

# %%
# %%R
# # Use ggplot2 to visualize a line plot showing PSC fluctuation over a trial
# # <YOUR CODE HERE>

# %% [markdown]
# ## **R Challenge: Create Columns with Averaged Values**

# %% [markdown]
# Next we want to break the time points of PSC into averaged 'sections' as they appeared to participants in the experiment. From `2s` to `4s`, participants either made a choice or watched a choice made between two different cards, so we'll call this the `card` section. From `6s` to `8s`, participants saw a video displaying the outcome of their card choice, so we'll call this the `video` section. Immediately afterward (from `10s` to `12s`), they made a judgment about how morally wrong the action was, so we call this the `judgment` section of the task.
#
# Please make 3 new columns, one for each section: `card`, `video`, and `judgment`

# %%
# %%R
# # Create and populate card, video, and judgment columns
# # <YOUR CODE HERE>

# %% [markdown]
# Looking just at the `self` and `other` data, we now want to answer the following questions: Is there a two-way interaction between agent and outcome conditions in how they relate to PSC in the RTPJ during the card section? What about the video section? And what about during the judgment section? Is there a main effect of either agent or outcome conditions on PSC in any of these sections?
#
# There are several ways you might test these questions. You could run a 2 (agent) x 2 (outcome) repeated-measures ANOVA, or you could implement linear mixed effects models. Your choice!
#
# Please note that R distinguishes between variables of type `factor` and `numeric` when running linear mixed effects models. Anything you are including as a categorical variable in the model, such as agent type or outcome, should be coded as a factor. Anything on a scale, such as a wrongness rating, should be coded as a numeric variable. You can convert a column to factor/numeric like so:
#
# In base R:
#
# ```{r}
# %%R
# data$column_name1 <- as.factor(data$column_name1)
# data$column_name2 <- as.numeric(data$column_name2)
# ```
#
# Or, with tidyverse syntax:
# ```{r}
# %%R
# library(tidyverse)
#
# df <- df %>%
#   mutate(
#     column_name1 = as.factor(column_name1),
#     column_name2 = as.numeric(column_name2)
#   )
# ```

# %% [markdown]
# Test main effects and the 2 (agent) x 2 (outcome) interaction for all three sections (i.e., card, video and judgment) separately, then report your results in 1–2 sentences!

# %%
# %%R
# # Test main effects and the 2 (agent) x 2 (outcome) interaction
# # <YOUR CODE HERE>

# %% [markdown]
# `<YOUR EXPLANATION HERE>`
